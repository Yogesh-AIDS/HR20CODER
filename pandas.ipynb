# %%
import pandas as pd
import numpy as np

# %%
subs = pd.read_csv("/content/subs (1).csv")

# %%
print(subs)
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
subs.value_counts()
# Out:
# Subscribers gained
# 105                   9
# 108                   6
# 88                    5
# 72                    5
# 123                   5
#                      ..
# 295                   1
# 301                   1
# 306                   1
# 312                   1
# 396                   1
# Name: count, Length: 180, dtype: int64

# %%
subs.sample()
# Out:
#      Subscribers gained
# 211                  98

# %%
subs.head(5)
# Out:
#    Subscribers gained
# 0                  48
# 1                  57
# 2                  40
# 3                  43
# 4                  44

# %%
subs.tail(5)
# Out:
#      Subscribers gained
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172

# %% [markdown]
# series math method

# %%
subs.count()
# Out:
# Subscribers gained    365
# dtype: int64

# %%
subs.sum()
# Out:
# Subscribers gained    49510
# dtype: int64

# %%
subs.prod()
# Out:
# Subscribers gained    0
# dtype: int64

# %%
subs.mean()
# Out:
# Subscribers gained    135.643836
# dtype: float64

# %%
subs.median()
# Out:
# Subscribers gained    123.0
# dtype: float64

# %%
subs.std()
# Out:
# Subscribers gained    62.675023
# dtype: float64

# %%
subs.var()
# Out:
# Subscribers gained    3928.158513
# dtype: float64

# %%
subs.iloc[-1]
# Out:
# Subscribers gained    172
# Name: 364, dtype: int64

# %%
subs.loc[7:9]  # mainly use for indexing
# Out:
#    Subscribers gained
# 7                  40
# 8                  44
# 9                  74

# %%
subs[-5:]
# Out:
#      Subscribers gained
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172

# %%
subs[::2]  # same as a for range function
# Out:
#      Subscribers gained
# 0                    48
# 2                    40
# 4                    44
# 6                    33
# 8                    44
# ..                  ...
# 356                 156
# 358                 210
# 360                 231
# 362                 155
# 364                 172
#
# [183 rows x 1 columns]

# %%
subs.loc[[1,3,2,7]]
# Out:
#    Subscribers gained
# 1                  57
# 3                  43
# 2                  40
# 7                  40

# %% [markdown]
# Editing series

# %%
subs[1]=100
subs
# Out:
#      Subscribers gained    1
# 0                    48  100
# 1                    57  100
# 2                    40  100
# 3                    43  100
# 4                    44  100
# ..                  ...  ...
# 360                 231  100
# 361                 226  100
# 362                 155  100
# 363                 144  100
# 364                 172  100
#
# [365 rows x 2 columns]

# %%
subs['evs']=100
subs
# Out:
#      Subscribers gained    1  evs
# 0                    48  100  100
# 1                    57  100  100
# 2                    40  100  100
# 3                    43  100  100
# 4                    44  100  100
# ..                  ...  ...  ...
# 360                 231  100  100
# 361                 226  100  100
# 362                 155  100  100
# 363                 144  100  100
# 364                 172  100  100
#
# [365 rows x 3 columns]

# %%
subs[0]=1
subs
# Out:
#      Subscribers gained    1  evs  0
# 0                    48  100  100  1
# 1                    57  100  100  1
# 2                    40  100  100  1
# 3                    43  100  100  1
# 4                    44  100  100  1
# ..                  ...  ...  ... ..
# 360                 231  100  100  1
# 361                 226  100  100  1
# 362                 155  100  100  1
# 363                 144  100  100  1
# 364                 172  100  100  1
#
# [365 rows x 4 columns]

# %%
subs[0:1]=[10,10]
subs
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_429/3098622618.py in <cell line: 0>()
# ----> 1 subs[0:1]=[10,10]
#       2 subs
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    4292         if isinstance(key, slice):
#    4293             slc = self.index._convert_slice_indexer(key, kind="getitem")
# -> 4294             return self._setitem_slice(slc, value)
#    4295
#    4296         if isinstance(key, DataFrame) or getattr(key, "ndim", None) == 2:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in _setitem_slice(self, key, value)
#    4316         #  backwards-compat, xref GH#31469
#    4317         self._check_setitem_copy()
# -> 4318         self.iloc[key] = value
#    4319
#    4320     def _setitem_array(self, key, value):
#
# ...

# %% [markdown]
# problem

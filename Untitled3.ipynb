# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbs

# %%
df = pd.read_csv('/content/loan_approval_dataset.csv')
df
# Out:
#       loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0           1                  2       Graduate             No        9600000
# 1           2                  0   Not Graduate            Yes        4100000
# 2           3                  3       Graduate             No        9100000
# 3           4                  3       Graduate             No        8200000
# 4           5                  5   Not Graduate            Yes        9800000
# ...       ...                ...            ...            ...            ...
# 4264     4265                  5       Graduate            Yes        1000000
# 4265     4266                  0   Not Graduate            Yes        3300000
# 4266     4267                  2   Not Graduate             No        6500000
# 4267     4268                  1   Not Graduate             No        4100000
# 4268     4269                  1       Graduate             No        9200000
#
# ...

# %%
df.isnull().sum()
# Out:
# loan_id                      0
#  no_of_dependents            0
#  education                   0
#  self_employed               0
#  income_annum                0
#  loan_amount                 0
#  loan_term                   0
#  cibil_score                 0
#  residential_assets_value    0
#  commercial_assets_value     0
#  luxury_assets_value         0
#  bank_asset_value            0
#  loan_status                 0
# dtype: int64

# %%
df.sample(10)
# Out:
#       loan_id   no_of_dependents      education  self_employed   income_annum  \
# 400       401                  4       Graduate             No        5400000
# 3445     3446                  3       Graduate             No        6600000
# 2370     2371                  3       Graduate            Yes         300000
# 3208     3209                  4       Graduate             No        4600000
# 3010     3011                  2       Graduate             No        1900000
# 2501     2502                  4       Graduate            Yes        7200000
# 3199     3200                  0       Graduate             No        3100000
# 343       344                  1       Graduate            Yes        3700000
# 2361     2362                  2   Not Graduate            Yes        8300000
# 2421     2422                  4       Graduate            Yes        4700000
#
#        loan_amount   loan_term   cibil_score   residential_assets_value  \
# ...

# %%
df.describe()
# Out:
#            loan_id   no_of_dependents   income_annum   loan_amount  \
# count  4269.000000        4269.000000   4.269000e+03  4.269000e+03
# mean   2135.000000           2.498712   5.059124e+06  1.513345e+07
# std    1232.498479           1.695910   2.806840e+06  9.043363e+06
# min       1.000000           0.000000   2.000000e+05  3.000000e+05
# 25%    1068.000000           1.000000   2.700000e+06  7.700000e+06
# 50%    2135.000000           3.000000   5.100000e+06  1.450000e+07
# 75%    3202.000000           4.000000   7.500000e+06  2.150000e+07
# max    4269.000000           5.000000   9.900000e+06  3.950000e+07
#
#          loan_term   cibil_score   residential_assets_value  \
# count  4269.000000   4269.000000               4.269000e+03
# mean     10.900445    599.936051               7.472617e+06
# std       5.709187    172.430401               6.503637e+06
# min       2.000000    300.000000              -1.000000e+05
# ...

# %%
df.shape
# Out:
# (4269, 13)

# %%
df.count()
# Out:
# loan_id                      4269
#  no_of_dependents            4269
#  education                   4269
#  self_employed               4269
#  income_annum                4269
#  loan_amount                 4269
#  loan_term                   4269
#  cibil_score                 4269
#  residential_assets_value    4269
#  commercial_assets_value     4269
#  luxury_assets_value         4269
#  bank_asset_value            4269
#  loan_status                 4269
# dtype: int64

# %%
df.columns
# Out:
# Index(['loan_id', ' no_of_dependents', ' education', ' self_employed',
#        ' income_annum', ' loan_amount', ' loan_term', ' cibil_score',
#        ' residential_assets_value', ' commercial_assets_value',
#        ' luxury_assets_value', ' bank_asset_value', ' loan_status'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df[' income_annum'].max()
# Out:
# 9900000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   loan_id                    4269 non-null   int64
#  1    no_of_dependents          4269 non-null   int64
#  2    education                 4269 non-null   object
#  3    self_employed             4269 non-null   object
#  4    income_annum              4269 non-null   int64
#  5    loan_amount               4269 non-null   int64
#  6    loan_term                 4269 non-null   int64
#  7    cibil_score               4269 non-null   int64
#  8    residential_assets_value  4269 non-null   int64
#  9    commercial_assets_value   4269 non-null   int64
#  10   luxury_assets_value       4269 non-null   int64
#  11   bank_asset_value          4269 non-null   int64
#  12   loan_status               4269 non-null   object
# dtypes: int64(10), object(3)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   loan_id                    4269 non-null   int64
#  1    no_of_dependents          4269 non-null   int64
#  2    education                 4269 non-null   object
#  3    self_employed             4269 non-null   object
#  4    income_annum              4269 non-null   int64
#  5    loan_amount               4269 non-null   int64
#  6    loan_term                 4269 non-null   int64
#  7    cibil_score               4269 non-null   int64
#  8    residential_assets_value  4269 non-null   int64
#  9    commercial_assets_value   4269 non-null   int64
#  10   luxury_assets_value       4269 non-null   int64
#  11   bank_asset_value          4269 non-null   int64
#  12   loan_status               4269 non-null   object
# dtypes: int64(10), object(3)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   loan_id                    4269 non-null   int64
#  1    no_of_dependents          4269 non-null   int64
#  2    education                 4269 non-null   object
#  3    self_employed             4269 non-null   object
#  4    income_annum              4269 non-null   int64
#  5    loan_amount               4269 non-null   int64
#  6    loan_term                 4269 non-null   int64
#  7    cibil_score               4269 non-null   int64
#  8    residential_assets_value  4269 non-null   int64
#  9    commercial_assets_value   4269 non-null   int64
#  10   luxury_assets_value       4269 non-null   int64
#  11   bank_asset_value          4269 non-null   int64
#  12   loan_status               4269 non-null   object
# dtypes: int64(10), object(3)
# ...

# %%
df[' cibil_score'].sort_values(ascending=False)
# Out:
# 821     900
# 3621    900
# 2473    900
# 373     900
# 1867    900
#        ...
# 1776    300
# 3038    300
# 3728    300
# 4252    300
# 2596    300
# Name:  cibil_score, Length: 4269, dtype: int64

# %%
plt.figure(figsize=(10,5))
plt.scatter(df[' loan_amount'],df[' income_annum'])
plt.title('loan_amount vs loan_status')
plt.xlabel('loan_amount')
plt.ylabel('loan_status')
# Out:
# Text(0, 0.5, 'loan_status')

# %%
dd= pd.read_csv('/content/Ecommerce_Consumer_Behavior_Analysis_Data.csv')
dd
# Out:
#      Customer_ID  Age  Gender Income_Level Marital_Status Education_Level  \
# 0    37-611-6911   22  Female       Middle        Married      Bachelor's
# 1    29-392-9296   49    Male         High        Married     High School
# 2    84-649-5117   24  Female       Middle         Single        Master's
# 3    48-980-6078   29  Female       Middle         Single        Master's
# 4    91-170-9072   33  Female       Middle        Widowed     High School
# ..           ...  ...     ...          ...            ...             ...
# 995  20-562-2569   44  Female         High       Divorced      Bachelor's
# 996  41-366-4205   50  Female         High         Single     High School
# 997  77-241-7621   26    Male         High        Married      Bachelor's
# 998  53-091-2176   21  Female         High        Widowed      Bachelor's
# 999  48-203-9118   21  Female       Middle         Single     High School
#
#     Occupation    Location     Purchase_Category Purchase_Amount  ...  \
# ...

# %%
df.isnull().sum()
# Out:
# loan_id                      0
#  no_of_dependents            0
#  education                   0
#  self_employed               0
#  income_annum                0
#  loan_amount                 0
#  loan_term                   0
#  cibil_score                 0
#  residential_assets_value    0
#  commercial_assets_value     0
#  luxury_assets_value         0
#  bank_asset_value            0
#  loan_status                 0
# dtype: int64

# %%
df.shape
# Out:
# (4269, 13)

# %%
plt.figure(figsize=(10,5))
plt.barh(dd['Gender'],dd['Marital_Status'])
plt.title('Gender vs Marital_Status')
plt.xlabel('Gender')
plt.grid()
plt.ylabel('Marital_Status')
# Out:
# Text(0, 0.5, 'Marital_Status')
